# %% [markdown]
# **With using convolutional neural network**, we are going to classify multi-selectional choice problems with MNIST fashion set data

# %%
# !nvidia-smi
# Out:
# Wed Jun 28 13:05:11 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.47                 Driver Version: 531.68       CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3080 L...    On | 00000000:01:00.0 Off |                  N/A |
# | N/A   60C    P8               11W /  N/A|     13MiB /  8192MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A       446      G   /Xwayland                                 N/A      |
# +---------------------------------------------------------------------------------------+

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split

(train_input, train_target), (test_input, test_target) = \
    keras.datasets.fashion_mnist.load_data()

train_scaled = train_input.reshape(-1, 28, 28, 1) / 255.0

train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
model = keras.Sequential()

model.add(keras.layers.Conv2D(32, kernel_size=3,
                                  activation='relu',
                                  padding='same',
                                  input_shape=(28,28,1)))
    # use 32 filters (kernels)
    # kernel size is (3, 3)
    # relu activation function
    # same padding is used
    # input will be the single image (28 * 28 * 1(depth, only monocolor picture))

# %%
model.add(keras.layers.MaxPooling2D(2))     # apply 2X2 pooling

# Pooling decreases the size of the feature, now (14, 14, 3)

# %%
model.add(keras.layers.Conv2D(64, kernel_size = 3, activation = "relu", padding = "same"))      # increase filter count to 64
model.add(keras.layers.MaxPooling2D(2))

# Pooling decreases the sisze of the feature, now (7, 7, 64) <--- why 64? That's because of the increment of the filter counte

# %%
# Because the final 10 neuron will calculate the possiblity for classification, we need to do flattening
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100, activation = "relu"))         # more and more hidden layer
model.add(keras.layers.Dropout(0.4))                            # prevent overfitting
model.add(keras.layers.Dense(10, activation = "softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 100)               313700
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 333,526
# Trainable params: 333,526
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model)

# %%
keras.utils.plot_model(model, show_shapes = True)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
              metrics='accuracy')

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-cnn-model.h5',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=2,
                                                  restore_best_weights=True)

history = model.fit(train_scaled, train_target, epochs=20,
                    validation_data=(val_scaled, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 13s 5ms/step - loss: 0.5329 - accuracy: 0.8078 - val_loss: 0.3335 - val_accuracy: 0.8768
# Epoch 2/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3509 - accuracy: 0.8743 - val_loss: 0.2773 - val_accuracy: 0.8992
# Epoch 3/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.3010 - accuracy: 0.8920 - val_loss: 0.2539 - val_accuracy: 0.9077
# Epoch 4/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2701 - accuracy: 0.9021 - val_loss: 0.2393 - val_accuracy: 0.9103
# Epoch 5/20
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2449 - accuracy: 0.9111 - val_loss: 0.2362 - val_accuracy: 0.9130
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2249 - accuracy: 0.9174 - val_loss: 0.2338 - val_accuracy: 0.9122
# Epoch 7/20
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.2081 - accuracy: 0.9239 - val_loss: 0.2254 - val_accuracy: 0.9177
# Epoch 8/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1941 - accuracy: 0.9275 - val_loss: 0.2184 - val_accuracy: 0.9181
# Epoch 9/20
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.1804 - accuracy: 0.9304 - val_loss: 0.2278 - val_accuracy: 0.9176
# Epoch 10/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1668 - accuracy: 0.9375 - val_loss: 0.2278 - val_accuracy: 0.9179

# %%
# Visualize the performance
import matplotlib.pyplot as plt

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(["train", "val"])

plt.show()

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2184 - accuracy: 0.9181
# [0.21841196715831757, 0.9180833101272583]

# %%
# Visualize the first image

plt.imshow(val_scaled[0].reshape(28, 28), cmap = "gray_r")
plt.show()

# %%
#preds = model.predict(val_scaled[0])           # <--- [X] (28, 28, 1)
preds = model.predict(val_scaled[0 : 1])        # <--- [O] (1, 28, 28, 1)  (batch dimension)
print(preds)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [[6.1456281e-18 7.9646071e-24 5.0706410e-21 4.5725671e-19 9.3983864e-18
#   5.6253062e-16 6.8886344e-18 5.0192956e-21 1.0000000e+00 3.6124610e-23]]

# %%
# Visualize the probability
plt.bar(range(1, 11), preds[0])
plt.xlabel("class")
plt.ylabel("probability")

plt.show()

# %%
# Visualize the probability
plt.bar(range(1, 11), preds[0])
plt.xlabel("class")
plt.ylabel("probability")
plt.yscale("log")               # <--- too smol, let's see logarithmic axis!

plt.show()

# %%
classes = ["t-shirt", "pants", "sweater", "dress", "coat", "sandel", "shirt", "sneakers", "bag", "ankle boots"]

# %%
import numpy as np
print(classes[np.argmax(preds)])            # Which is the first prediction?
# Out:
# bag

# %%
test_scaled = test_input.reshape(-1, 28, 28, 1) / 255.0

# %%
model.evaluate(test_scaled, test_target)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2442 - accuracy: 0.9134
# [0.24424098432064056, 0.9133999943733215]

# %% [markdown]
# The current model roughly expects ~91.3% of accuracy in real given data

# %% [markdown]
# **Deep inspection of the model prediction**

# %%
model_prediction_result = model.predict(test_scaled)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
model_prediction_result = [classes[np.argmax(x)] for x in model_prediction_result]
model_prediction_answer = [classes[x] for x in test_target]

# %%
print(model_prediction_result)
# Out:
# ['ankle boots', 'sweater', 'pants', 'pants', 'shirt', 'pants', 'coat', 'shirt', 'sandel', 'sneakers', 'coat', 'sandel', 'sandel', 'dress', 'coat', 'pants', 'sweater', 'coat', 'bag', 't-shirt', 'sweater', 'sandel', 'sneakers', 'sandel', 'pants', 'sweater', 'shirt', 't-shirt', 'ankle boots', 'dress', 'bag', 'bag', 'dress', 'dress', 'bag', 't-shirt', 'sneakers', 'sandel', 'sneakers', 'ankle boots', 't-shirt', 'pants', 't-shirt', 'sneakers', 'shirt', 'sneakers', 'sweater', 'pants', 'sweater', 'shirt', 'coat', 'coat', 'sandel', 'bag', 'sweater', 'sweater', 'bag', 'coat', 'bag', 't-shirt', 'sneakers', 'sneakers', 'bag', 'sandel', 'pants', 'pants', 'sweater', 'dress', 'sneakers', 'bag', 'sneakers', 't-shirt', 'sweater', 'shirt', 'sweater', 'dress', 'pants', 'sweater', 'bag', 'coat', 'pants', 'bag', 'sandel', 'ankle boots', 'sandel', 't-shirt', 'dress', 'sweater', 't-shirt', 'sweater', 'sandel', 'dress', 'shirt', 'sneakers', 'pants', 'bag', 't-shirt', 'pants', 'sweater', 'sweater', 'dress', 'shirt', 'sneakers', 'shirt', 'sneakers', 'bag', 'sandel', 'ankle boots', 'ankle boots', 'coat', 'sweater', 'sandel', 'sneakers', 't-shirt', 'sandel', 'sweater', 'bag', 'coat', 'sneakers', 'bag', 't-shirt', 't-shirt', 'ankle boots', 'ankle boots', 'dress', 't-shirt', 'bag', 'coat', 'pants', 'sandel', 'coat', 'pants', 'ankle boots', 'pants', 'bag', 'shirt', 'sweater', 'pants', 'sweater', 'sandel', 'pants', 't-shirt', 't-shirt', 't-shirt', 'pants', 'shirt', 'pants', 'dress', 'sweater', 'sweater', 'dress', 'coat', 'pants', 'coat', 'sandel', 't-shirt', 'coat', 'sneakers', 'ankle boots', 'dress', 'sneakers', 'sweater', 'dress', 'ankle boots', 't-shirt', 'ankle boots', 'coat', 'sneakers', 'coat', 'sweater', 't-shirt', 'sandel', 'sweater', 'pants', 'sweater', 'pants', 'dress', 't-shirt', 'ankle boots', 'pants', 't-shirt', 'ankle boots', 'dress', 'shirt', 'sneakers', 'ankle boots', 'ankle boots', 'coat', 'coat', 'sneakers', 'pants', 'sweater', 'pants', 'shirt', 'dress', 'sweater', 'bag', 'dress', 'shirt', 'pants', 'pants', 't-shirt', 'sweater', 'ankle boots', 'sweater', 'coat', 't-shirt', 'sneakers', 'ankle boots', 'bag', 'coat', 'pants', 'bag', 'coat', 'pants', 'dress', 'pants', 'coat', 'sneakers', 'sweater', 'bag', 'sandel', 'sweater', 't-shirt', 'sneakers', 'sneakers', 'shirt', 'shirt', 'sneakers', 't-shirt', 'sneakers', 'bag', 'ankle boots', 'sweater', 'ankle boots', 't-shirt', 'sandel', 'pants', 'coat', 'sweater', 'sandel', 'coat', 'ankle boots', 'sweater', 'sweater', 'bag', 'shirt', 'coat', 'shirt', 'sweater', 'sneakers', 'sneakers', 't-shirt', 'sandel', 'sandel', 'sweater', 'bag', 'sandel', 'sweater', 'dress', 't-shirt', 'coat', 'bag', 't-shirt', 't-shirt', 'shirt', 'dress', 'bag', 'ankle boots', 'shirt', 'pants', 'shirt', 't-shirt', 'sweater', 'dress', 't-shirt', 'bag', 'dress', 'sneakers', 'coat', 't-shirt', 'pants', 'shirt', 'dress', 't-shirt', 'shirt', 'shirt', 'sneakers', 'sandel', 'coat', 'sandel', 'ankle boots', 'sandel', 'shirt', 'sandel', 'sandel', 'pants', 'ankle boots', 'bag', 'bag', 'dress', 'dress', 'shirt', 'bag', 't-shirt', 't-shirt', 'sweater', 'ankle boots', 'sneakers', 'sneakers', 'pants', 'dress', 'shirt', 'coat', 'sweater', 'coat', 'sneakers', 'pants', 'shirt', 'coat', 'bag', 'sweater', 'shirt', 'sandel', 'coat', 'sweater', 'sneakers', 'sneakers', 'sneakers', 'dress', 'dress', 'sneakers', 'coat', 'sneakers', 'pants', 'dress', 'sneakers', 'sweater', 'sweater', 'dress', 'coat', 't-shirt', 'dress', 'pants', 'shirt', 'pants', 'ankle boots', 'coat', 'ankle boots', 'ankle boots', 'pants', 'sneakers', 't-shirt', 'dress', 'shirt', 't-shirt', 'sweater', 'coat', 'bag', 't-shirt', 'pants', 'shirt', 'sweater', 'coat', 'coat', 'sneakers', 'dress', 'sweater', 'sweater', 'sandel', 't-shirt', 'sneakers', 'ankle boots', 'coat', 't-shirt', 'ankle boots', 'dress', 'ankle boots', 'dress', 'shirt', 'sandel', 'shirt', 't-shirt', 'dress', 'sandel', 'bag', 'pants', 'shirt', 'sweater', 'shirt', 'shirt', 'coat', 'sneakers', 'sandel', 'sweater', 't-shirt', ...

# %%
print(model_prediction_answer)
# Out:
le boots', 'sweater', 'shirt', 'bag', 'shirt', 'coat', 'sweater', 'sweater', 'ankle boots', 'sneakers', 'shirt', 'sandel', 'sandel', 'sweater', 'bag', 'sandel', 'sweater', 'dress', 't-shirt', 'coat', 'bag', 't-shirt', 't-shirt', 'shirt', 'dress', 'bag', 'ankle boots', 'shirt', 'pants', 'dress', 't-shirt', 'sweater', 'dress', 't-shirt', 'bag', 'dress', 'sneakers', 'coat', 't-shirt', 'pants', 'shirt', 'dress', 't-shirt', 'shirt', 'shirt', 'sneakers', 'sandel', 'coat', 'sandel', 'ankle boots', 'sandel', 'shirt', 'sandel', 'sandel', 'pants', 'ankle boots', 'bag', 'bag', 'dress', 'dress', 'shirt', 'bag', 't-shirt', 't-shirt', 'sweater', 'ankle boots', 'sneakers', 'sneakers', 'pants', 'dress', 'shirt', 'coat', 'sweater', 'coat', 'ankle boots', 'pants', 'shirt', 'coat', 'bag', 'sweater', 'shirt', 'sandel', 'coat', 'shirt', 'sneakers', 'sneakers', 'sneakers', 'dress', 'dress', 'sneakers', 't-shirt', 'sneakers', 'pants', 'dress', 'sneakers', 'sweater', 'sweater', 'dress', 'coat', 't-shirt', 'dress', 'pants', 'shirt', 'pants', 'ankle boots', 'coat', 'ankle boots', 'ankle boots', 'pants', 'sneakers', 'bag', 'dress', 'shirt', 't-shirt', 'sweater', 'coat', 'bag', 't-shirt', 'pants', 'sweater', 'sweater', 'coat', 'coat', 'sneakers', 'dress', 'sweater', 'sweater', 'sandel', 't-shirt', 'sneakers', 'ankle boots', 'coat', 't-shirt', 'ankle boots', 'dress', 'ankle boots', 'coat', 'sweater', 'sandel', 't-shirt', 'sweater', 'dress', 'sandel', 'bag', 'pants', 'shirt', 'sweater', 'shirt', 'shirt', 'coat', 'ankle boots', 'sandel', 'sweater' ...

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(model_prediction_result, model_prediction_answer)
# Out:
# array([[957,   0,   1,   0,   0,   1,   0,  13,   0,   1],
#        [  0, 983,   3,   0,   2,   0,  10,   0,   1,   3],
#        [  0,   4, 888,  23,   0,   0,  92,   0,  69,   5],
#        [  0,   3,  34, 932,   8,   0,  31,   0,   5,  19],
#        [  0,   1,   0,   4, 985,   0,   0,   0,   1,   0],
#        [  6,   1,   0,   0,   0, 989,   0,   9,   0,   1],
#        [  1,   1,  24,  17,   4,   0, 666,   0,  37,  69],
#        [ 36,   2,   0,   0,   0,  10,   0, 978,   0,   0],
#        [  0,   1,  49,   9,   0,   0,  69,   0, 872,  18],
#        [  0,   4,   1,  15,   1,   0, 132,   0,  15, 884]])

# %%
from pandas import DataFrame
import seaborn as sns

sns.set(rc={'figure.figsize':(15, 10)})

df_confusion_matrix = DataFrame(confusion_matrix(model_prediction_result, model_prediction_answer))
sns.heatmap(df_confusion_matrix, cmap = "Blues",fmt = "d", annot = True)
# Out:
# <Axes: >
