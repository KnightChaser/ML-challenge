# %%
from tensorflow import keras

(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

# %%
# Convert the pixel value(0 ~ 255) into 0 ~ 1 scope
# Expand a 28 * 28 size 2-dimensional array to a 1-dimensional array which length is 784
# Then divide the data into training stes and data sets
from sklearn.model_selection import train_test_split

train_scaled = train_input / 255.0
train_scaled = train_scaled.reshape(-1, 28 * 28)
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size = 0.2, random_state = 42)

# %%
# Use sigmoid function as activation function at the dense layer of the neural network
dense1 = keras.layers.Dense(100, activation = "sigmoid", input_shape = (784, ))        # has 100 neurons
dense2 = keras.layers.Dense(10,  activation = "softmax")

# %%
# Create a deep neural network sequentially, with denseN objects
model = keras.Sequential([dense1, dense2])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 100)               78500
#
#  dense_20 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Add more layers at once
model = keras.Sequential([
    keras.layers.Dense(100, activation = "sigmoid", input_shape = (784, ), name = "hidden"),
    keras.layers.Dense(10,  activation = "softmax", name = "output")
], name = "Fashion MNIST model")

# %%
model.summary()
# Out:
# Model: "Fashion MNIST model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 100)               78500
#
#  output (Dense)              (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# by using add() method, conveniently append more layers to the neural network
model = keras.Sequential()
model.add(keras.layers.Dense(100, activation = "sigmoid", input_shape = (784, )))
model.add(keras.layers.Dense(10,  activation = "softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 100)               78500
#
#  dense_22 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = "sparse_categorical_crossentropy", metrics = "accuracy")
model.fit(train_scaled, train_target, epochs = 5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.5670 - accuracy: 0.8067
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4114 - accuracy: 0.8514
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3746 - accuracy: 0.8633
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3518 - accuracy: 0.8727
# Epoch 5/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3360 - accuracy: 0.8775

# %%
# What if I add more and more layers?
# by using add() method, conveniently append more layers to the neural network
model = keras.Sequential()
model.add(keras.layers.Dense(100, activation = "sigmoid", input_shape = (784, )))
model.add(keras.layers.Dense(10,  activation = "softmax"))
model.add(keras.layers.Dense(10,  activation = "softmax"))
model.add(keras.layers.Dense(10,  activation = "softmax"))

model.compile(loss = "sparse_categorical_crossentropy", metrics = "accuracy")
model.fit(train_scaled, train_target, epochs = 5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 2.0774 - accuracy: 0.1941
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 1.7717 - accuracy: 0.2541
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 1.5534 - accuracy: 0.3244
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 1.3355 - accuracy: 0.4251
# Epoch 5/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 1.1970 - accuracy: 0.4819

# %%
model = keras.Sequential()

model.add(keras.layers.Flatten(input_shape = (28, 28)))
model.add(keras.layers.Dense(100, activation = "relu"))
model.add(keras.layers.Dense(10,  activation = "softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_27 (Dense)            (None, 100)               78500
#
#  dense_28 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Run with ReLU
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
train_scaled = train_input / 255.0
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size = 0.2, random_state= 42)

# %%
model.compile(loss = "sparse_categorical_crossentropy", metrics = "accuracy")
model.fit(train_scaled, train_target, epochs = 5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5275 - accuracy: 0.8141
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3929 - accuracy: 0.8573
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3553 - accuracy: 0.8715
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3337 - accuracy: 0.8800
# Epoch 5/5
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3194 - accuracy: 0.8858

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 1s 1ms/step - loss: 0.3382 - accuracy: 0.8827
# [0.33824461698532104, 0.8826666474342346]

# %%
# model.compile(optimizer = "SGD", loss = "sparse_categorical_crossentropy", metrics = "accuracy")

# %%
# Adam
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape = (28, 28)))
model.add(keras.layers.Dense(100, activation = "relu"))
model.add(keras.layers.Dense(10, activation = "softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_29 (Dense)            (None, 100)               78500
#
#  dense_30 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = "accuracy")

# %%
model.fit(train_scaled, train_target, epochs = 5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.5246 - accuracy: 0.8176
# Epoch 2/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3917 - accuracy: 0.8606
# Epoch 3/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3509 - accuracy: 0.8727
# Epoch 4/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3243 - accuracy: 0.8810
# Epoch 5/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3047 - accuracy: 0.8880

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3616 - accuracy: 0.8651
# [0.3615623712539673, 0.8650833368301392]
